# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253E/blob/main/algo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="teh"
b="kopi"

c=a
a=b
b=c

print(f"Isi gelas A adalah {a}")
print(f"Isi gelas B adalah {b}")
# Out:
# Isi gelas A adalah kopi
# Isi gelas B adalah teh

# %%
a=10
a=90
a=8
a=0
a=12

print(a)
# Out:
# 12

# %%
a,b=10,5

a=b  # a=b ==> a=5
b=a  # b=a ==> b=5

print(f"Nilai a={a}")
print(f"Nilai b={b}")
# Out:
# Nilai a=5
# Nilai b=5

# %%
a,b=10,5

c=a  # c=10
a=b  # a=b ==> a=5
b=c  # b=c ==> b=10

print(f"Nilai a={a}")
print(f"Nilai b={b}")
# Out:
# Nilai a=5
# Nilai b=10
