# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253E/blob/main/algo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=61
a=n%2==0
b=n
print(f"nilai a={a}")
print(f"nilai b={b}")
# Out:
# nilai a=False
# nilai b=61

# %%
n=int(input("Masukkan sembarang nilai ?"))
if n%2==0:
  print(f"{n} adalah bilangan Genap")
else:
  print(f"{n} adalah bilangan Ganjil")
# Out:
# Masukkan sembarang nilai ?12
# 12 adalah bilangan Genap

# %%
70/60
# Out:
# 1.1666666666666667

# %%
int(70/60)
# Out:
# 1

# %%
n=int(input("Nilai n(detik) ?"))
menit=int(n/60)
detik=n%60

print(f"{n} detik menjadi {menit} menit {detik} detik")
# Out:
# Nilai n(detik) ?98
# 98 detik menjadi 1 menit 38 detik

# %%
alas=int(input("Masukkan nilai alas segitiga?"))
tinggi=int(input("Masukkan tinggi alas segitiga?"))
L=0.5*alas*tinggi
print(f"Luas segitiga dengan alas={alas} dan tinggi={tinggi} adalah {L}")
# Out:
# Masukkan nilai alas segitiga?10
# Masukkan tinggi alas segitiga?6
# Luas segitiga dengan alas=10 dan tinggi=6 adalah 30.0
