# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253E/blob/main/array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai_ke1=100
nilai_ke2=70
nilai_ke3=50

print(f"{nilai_ke1},{nilai_ke2},{nilai_ke3}")
# Out:
# 100,70,50

# %%
nilai=[100,70,50,60,80]
nama=['Fina','Gina','Yuni','Hafiz','Jenette']
data=['Cikarang',20,'Algoritma','Sepakbola']

# %%
#Nama Gina, nilai 100, karena dia suka Sepakbola
print(f"Nama {nama[1]} nilai {nilai[0]}, karena dia suka {data[3]}")
# Out:
# Nama Gina nilai 100, karena dia suka Sepakbola

# %%
#Hobby Hafiz Sepakbola dia tinggal di Cikarang temannya Jenette
print(f"Hobby {nama[3]} {data[3]} dia tinggal di {data[0]} temanya {nama[4]}")
# Out:
# Hobby Hafiz Sepakbola dia tinggal di Cikarang temanya Jenette

# %%
#Pada Mata Kuliah Algoritma nilai Yuni adalah 50
print(f"pada mata kuliah {data[-2]} nilai {nama[-3]} adalah {nilai[-3]}")
# Out:
# pada mata kuliah Algoritma nilai Yuni adalah 50

# %%
#Pada Mata Kuliah Algoritma nilai Yuni adalah 80
nilai[-3]=80
print(f"pada mata kuliah {data[-2]} nilai {nama[-3]} adalah {nilai[-3]}")
# Out:
# pada mata kuliah Algoritma nilai Yuni adalah 80

# %%
nama
# Out:
# ['Fina', 'Gina', 'Yuni', 'Hafiz', 'Jenette']

# %%
nama.append("Fani")
nama
# Out:
# ['Fina', 'Gina', 'Yuni', 'Hafiz', 'Jenette', 'Fani']

# %%
nama.insert(-1,"Kaka")
nama
# Out:
# ['Fina', 'Gina', 'Yuni', 'Hafiz', 'Jenette', 'Kaka', 'Fani']

# %%
nama[-4]="Levi"
nama
# Out:
# ['Fina', 'Gina', 'Yuni', 'Levi', 'Jenette', 'Kaka', 'Fani']

# %%
nama
# Out:
# ['Fina', 'Gina', 'Yuni', 'Levi', 'Jenette', 'Kaka', 'Fani']

# %%
nama.remove("Gina")
nama.pop(3)
nama
# Out:
# ['Fina', 'Yuni', 'Levi', 'Kaka', 'Fani']

# %%
len(nama)
# Out:
# 5

# %%
len(nilai)
# Out:
# 5

# %%
nama.append("Haifz")
nama.append("Janette")

# %%
#Jumlah data mahasiswa adalah 5
print(f"Jumlah data mahasiswa adalah {len(nama)}")
# Out:
# Jumlah data mahasiswa adalah 7

# %%
#Latihan-1 : Menyimpan 5 data buah dan menampilkan data array
buah=[]
for i in range(5):
  x=input(f"Masukkan nama buah ke-{i+1}?")
  buah.append(x)


print(buah)
# Out:
# Masukkan nama buah ke-1?Apel
# Masukkan nama buah ke-2?Anggur
# Masukkan nama buah ke-3?mangga
# Masukkan nama buah ke-4?Alpukat
# Masukkan nama buah ke-5?Melon
# ['Apel', 'Anggur', 'mangga', 'Alpukat', 'Melon']

# %%
nilai
# Out:
# [100, 70, 80, 60, 80]

# %%
jumlah=0
for i in nilai:
  jumlah +=i

print(f"Total nilai mahasiswa adalah {jumlah}")
print(f"Rata-rata nilai mahasiswa adalah : {jumlah/len(nilai)}")
# Out:
# Total nilai mahasiswa adalah 390
# Rata-rata nilai mahasiswa adalah : 78.0
